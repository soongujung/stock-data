# %% [markdown]
# # dataframe 내의 컬럼의 type 명시적 지정방식 정리
#
# ### 목표
# dataframe내의 특정 컬럼의 데이터 타입을 명시적으로 지정하는 방식을 정리한다. REST API에서 오는 데이터는 대부분 VALUE가 String이다. 따라서 insert시 형변환을 해주어야 한다.
#
# 여기서는 이런 이유로 dataframe에 다른 타입으로 데이터를 저장하는 예를 한국은행 데이터 파싱과정과 함께 정리한다.
#
# ### 작성이유
#
# - 프로젝트 초반에는 REST API로부터 받아온 스트링으로 넘어온 숫자 데이터를 그대로 DB에 저장했다.
# - 그리고 숫자에 관련된 DB컬럼 또한 스트링타입이었다.
#
# 초반 빠른 개발로 결과물을 확인하기 위한 방식이었는데, 어느정도 정제가 필요한 지금은 DATA_VALUE 컬럼을 float 타입으로 지정하고자 한다.
#
# - DATA_VALUE 컬럼을 float로 지정한 후에는
# - 크롤링코드에서 DataFrame으로 INSERT하는 로직을 변경해주어야 한다.

# %% [markdown]
# ## 의존성 import

# %%
#-*- coding:utf-8 -*-

import psycopg2
import pandas.io.sql as pandas_sql
from pandas import DataFrame
from sqlalchemy import create_engine
import urllib3
import json

# %% [markdown]
# ## database 접속정보 설정

# %%
dict_account = {
    'host': 'localhost',
    'dbname': 'stock_data',
    'user': 'postgres',
    'password': '1234'
}

conn_str = "host='{}' dbname='{}' user={} password={}"\
    .format(
        dict_account['host'],
        dict_account['dbname'],
        dict_account['user'],
        dict_account['password']
    )

alchemy_conn = create_engine(
    "postgresql://{}:{}@localhost:5432/{}"
        .format(
            dict_account['user'],
            dict_account['password'],
            dict_account['dbname']
        )
)

arr_columns = [
        'STAT_NAME',  'STAT_CODE',  'ITEM_CODE1', 'ITEM_CODE2', 'ITEM_CODE3',
        'ITEM_NAME1', 'ITEM_NAME2', 'ITEM_NAME3', 'DATA_VALUE', 'TIME'
    ]

dict_columns_type = {
    'STAT_NAME': 'str',
    'STAT_CODE': 'str',
    'ITEM_CODE1': 'str',
    'ITEM_CODE2': 'str',
    'ITEM_CODE3': 'str',
    'ITEM_NAME1': 'str',
    'ITEM_NAME2': 'str',
    'ITEM_NAME3': 'str',
    'DATA_VALUE': 'float',
    'TIME': 'str'
}

# %% [markdown]
# ## 한국은행 api 접근
# ### !!!! 주의) API 키를 꼭!!! 직접 입력해야 정상동작한다.
# ### 여기서는 API 키 노출문제로 지워놓음

# %%
url = "http://ecos.bok.or.kr/api/StatisticSearch/[api 키 입력!!]/json/kr/1/5000/064Y001/DD/20140101/20191231/0001000"

http = urllib3.PoolManager()
ret = http.request("GET", url, headers={'Content-Type': 'application/json'})

str_response = ret.data.decode('utf-8')
dict_data = json.loads(str_response)
arr_data = dict_data['StatisticSearch']['row']

# %%
# arr_data

# %% [markdown]
# ## pandas dataframe 내의 컬럼 데이터 타입 지정
#
# - **키워드 인자 dtype 을 명시적으로 지정하는 방식**
# https://cmdlinetips.com/2018/09/how-to-change-data-type-for-one-or-more-columns-in-pandas-dataframe/
# python 3.x 또는 pandas 버전에서 deprecated 된것으로 보인다.
#
#
# - **DataFrame이 생성된 후 column의 타입을 명시적으로 변경하는 방식**
# 해외자료
# https://github.com/pandas-dev/pandas/issues/9287
# https://stackoverflow.com/questions/41517273/how-to-change-pandas-category-type-using-a-dtype-dict
# 국내자료
# https://riptutorial.com/ko/pandas/example/10052/dtype-%EB%B3%80%EA%B2%BD%ED%95%98%EA%B8%B0

# %% [markdown]
# ### 1) 2차원 배열로 변환
# [dict1, dict2, dict3, .... dicti, .... dictn]
# 의 방식은 통하지 않는다.
#
# 따라서 2차원 배열의 형식으로 변환을 해주어야 한다.

# %%
# [[getattr(i,j) for j in arr_columns] for i in arr_data]
# 이상하게도 python 3.x 에서 getattr이 제대로 동작하지 않는다.

[[ dict_data[column_nm] for column_nm in arr_columns] for dict_data in arr_data]

# for i in arr_data:
#     for j in arr_columns:
#         print(i[j])

# for i in arr_data:
#     print(i['STAT_NAME'])

# arr_data[0]['STAT_NAME']
# Out:
# [['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1967.19',
#   '20140102'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1946.14',
#   '20140103'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1953.28',
#   '20140106'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1959.44',
#   '20140107'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1958.96',
#   '20140108'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1946.11',
#   '20140109'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1938.54',
#   '20140110'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1948.92',
#   '20140113'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1946.07',
#   '20140114'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1953.28',
#   '20140115'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1957.32',
#   '20140116'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1944.48',
#   '20140117'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1953.78',
#   '20140120'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1963.89',
#   '20140121'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1970.42',
#   '20140122'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1947.59',
#   '20140123'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1940.56',
#   '20140124'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1910.34',
#   '20140127'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1916.93',
#   '20140128'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1941.15',
#   '20140129'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1919.96',
#   '20140203'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1886.85',
#   '20140204'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1891.32',
#   '20140205'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1907.89',
#   '20140206'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1922.5',
#   '20140207'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1923.3',
#   '20140210'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1932.06',
#   '20140211'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1935.84',
#   '20140212'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1926.96',
#   '20140213'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1940.28',
#   '20140214'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1946.36',
#   '20140217'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1946.91',
#   '20140218'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1942.93',
#   '20140219'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1930.57',
#   '20140220'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1957.83',
#   '20140221'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1949.05',
#   '20140224'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1964.86',
#   '20140225'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1970.77',
#   '20140226'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1978.43',
#   '20140227'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1979.99',
#   '20140228'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1964.69',
#   '20140303'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1954.11',
#   '20140304'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1971.24',
#   '20140305'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1975.62',
#   '20140306'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1974.68',
#   '20140307'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1954.42',
#   '20140310'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1963.87',
#   '20140311'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1932.54',
#   '20140312'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1934.38',
#   '20140313'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1919.9',
#   '20140314'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1927.53',
#   '20140317'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1940.21',
#   '20140318'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1937.68',
#   '20140319'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1919.52',
#   '20140320'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1934.94',
#   '20140321'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1945.55',
#   '20140324'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1941.25',
#   '20140325'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1964.31',
#   '20140326'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1977.97',
#   '20140327'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1981',
#   '20140328'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1985.61',
#   '20140331'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1991.98',
#   '20140401'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1997.25',
#   '20140402'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1993.7',
#   '20140403'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1988.09',
#   '20140404'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1989.7',
#   '20140407'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1993.03',
#   '20140408'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1998.95',
#   '20140409'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2008.61',
#   '20140410'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1997.44',
#   '20140411'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1997.02',
#   '20140414'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1992.27',
#   '20140415'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1992.21',
#   '20140416'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1992.05',
#   '20140417'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2004.28',
#   '20140418'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1999.22',
#   '20140421'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2004.22',
#   '20140422'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2000.37',
#   '20140423'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '1998.34',
#   '20140424'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '
],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2510.12',
#   '20171205'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2474.37',
#   '20171206'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2461.98',
#   '20171207'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2464',
#   '20171208'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2471.49',
#   '20171211'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2461',
#   '20171212'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2480.55',
#   '20171213'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2469.48',
#   '20171214'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2482.07',
#   '20171215'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2481.88',
#   '20171218'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2478.53',
#   '20171219'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2472.37',
#   '20171220'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2429.83',
#   '20171221'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2440.54',
#   '20171222'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2427.34',
#   '20171226'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2436.67',
#   '20171227'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2467.49',
#   '20171228'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2479.65',
#   '20180102'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2486.35',
#   '20180103'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2466.46',
#   '20180104'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2497.52',
#   '20180105'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2513.28',
#   '20180108'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2510.23',
#   '20180109'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2499.75',
#   '20180110'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2487.91',
#   '20180111'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2496.42',
#   '20180112'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2503.73',
#   '20180115'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2521.74',
#   '20180116'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2515.43',
#   '20180117'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2515.81',
#   '20180118'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2520.26',
#   '20180119'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2502.11',
#   '20180122'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2536.6',
#   '20180123'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2538',
#   '20180124'],
#  ['6.1.1 주식시장(일별)',
#   '064Y001',
#   '0001000',
#   ' ',
#   ' ',
#   'KOSPI지수',
#   ' ',
#   ' ',
#   '2562.23',
#   '20180125'],
#  ...]

# %% [markdown]
# ### 2) 데이터 타입 변환

# %%
data_for_insert = [[ dict_data[column_nm] for column_nm in arr_columns] for dict_data in arr_data]

df_test = DataFrame(data_for_insert, columns=arr_columns)
df_test = df_test.astype(dtype=dict_columns_type)

# %% [markdown]
# ### 3) 변환결과 확인

# %%
df_test.dtypes
# Out:
# STAT_NAME      object
# STAT_CODE      object
# ITEM_CODE1     object
# ITEM_CODE2     object
# ITEM_CODE3     object
# ITEM_NAME1     object
# ITEM_NAME2     object
# ITEM_NAME3     object
# DATA_VALUE    float64
# TIME           object
# dtype: object

# %% [markdown]
# ## Dataframe 내에 api 결과 데이터 저장

# %%
df_kospi_insert = DataFrame(data_for_insert, columns=arr_columns)
df_kospi_insert = df_kospi_insert.astype(dtype=dict_columns_type)

# %% [markdown]
# ## Dataframe 내의 컬럼 data type 변경

# %%
df_kospi_insert.dtypes
# Out:
# STAT_NAME      object
# STAT_CODE      object
# ITEM_CODE1     object
# ITEM_CODE2     object
# ITEM_CODE3     object
# ITEM_NAME1     object
# ITEM_NAME2     object
# ITEM_NAME3     object
# DATA_VALUE    float64
# TIME           object
# dtype: object

# %%
df_kospi_insert
# Out:
#            STAT_NAME STAT_CODE ITEM_CODE1 ITEM_CODE2 ITEM_CODE3 ITEM_NAME1  \
# 0     6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# 1     6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# 2     6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# 3     6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# 4     6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# ...              ...       ...        ...        ...        ...        ...
# 1410  6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# 1411  6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# 1412  6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# 1413  6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
# 1414  6.1.1 주식시장(일별)   064Y001    0001000                          KOSPI지수
#
#      ITEM_NAME2 ITEM_NAME3  DATA_VALUE      TIME
# 0                              1967.19  20140102
# 1                              1946.14  20140103
# 2                              1953.28  20140106
# 3                              1959.44  20140107
# 4                              1958.96  20140108
# ...         ...        ...         ...       ...
# 1410                           2072.42  20191001
# 1411                           2031.91  20191002
# 1412                           2020.69  20191004
# 1413                           2021.73  20191007
# 1414                           2046.25  20191008
#
# [1415 rows x 10 columns]
